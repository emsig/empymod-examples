# %% [markdown]
# # Example benchmark for `empymod`
#
# Benchmark to check with method is fasted for the problem to solve, and check its precision.
#
# This example benchmark uses x-directed source and receiver in the seawater layer below air and above the subsurface layers. Source is at the origin and receivers are aligned along the x-axis.
# - *ab = 11*
# - freq = 1*
# - *lsrc = lrec* (source and receiver are in the same layer)
# - *aniso, epermH, epermV, mpermH, mpermV = None*
# - *xdirect = False*
#
# ### Your mileage may vary
# Adjust the parameters to resemble your problem at hand. Specifically **ab**, and the **number of layers between source and receiver**.

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rcParams

from empymod import dipole

# %matplotlib inline
# %load_ext memory_profiler

# Style adjustments
plt.style.use('ggplot')
rcParams['figure.dpi'] = 100
rcParams['savefig.dpi'] = 100
rcParams['text.usetex'] = True
rcParams['font.serif'] = 'Computer Modern Roman'
rcParams['font.family'] = 'serif'
rcParams['font.style'] = 'normal'

# %% [markdown]
# ## General model parameters

# %%
freq = 1
ab = 11
xdirect = False
verb = 0
zsrc = 990
zrec = 1000

# aHT : all hankel transforms in a list
aHT = ['QWE', 'FHT', 'FHT']

# aHTP : list of hankel transforms print name
aHTP = ['9pt QWE', '201pt FHT', '801pt FHT']

# aHTARG : list of arguments for hankel transforms
aHTARG = [[1e-6, 1e-24, 9, 40, 40], 'key_201_2012', 'anderson_801_1982']
# factor to decrase atol for the spline version of QWE, to much precision of spline version of filters
qwe_spline_fact = 1000

# aOPT : list of optimization arguments
aOPT = [None, 'parallel', 'spline']

# %% [markdown]
# ## Calculation & memory estimate for biggest model

# %%
# Initialize Output dict
runtimes = dict()

# Loop over the various hankel transforms
for i in range(np.size(aHT)):
    HT = aHT[i]
    HTP = aHTP[i]
    HTARG = aHTARG[i]
    runtimes[HTP] = dict()
    
    # Loop over the optimizations
    for opt in aOPT:
        runtimes[HTP][opt] = np.zeros(21)
        if HTP == 'QWE' and opt == 'spline':
            HTARG[0] *= qwe_spline_fact
        print('   **   '+ HTP + '; opt = '+str(opt)+'   **')
        
        # Loop over the 21 cases (layers: 5, 22, 100; offsets: 1, 3, 10, 32, 100, 316, 1000)
        for case in range(21):
            nlay = np.logspace(0.7,2,3, dtype=int)[case//7]      # Nr of layers: 5, 22, 100
            depth = np.r_[0, 1000+np.linspace(0, 5000, nlay-2)]  # Layer top depths
            res = np.r_[1e20, 0.3, np.linspace(.1, 10, nlay-2)]  # Layer resistivities (ohm-m)
            
            noff = int(10**(case%7/2))                           # Nr of offsets: 1, 10, 100, 1000
            rec   = [np.linspace(500, min(20000, noff*500+500), noff), np.zeros(noff), zrec]

            # === EM-FIELD CALCULATION ============
            out = %timeit -q -o dipole([0, 0, zsrc], rec, depth, res, freq, ab=ab, ht=HT, htarg=HTARG, opt=opt, verb=0)
            if case == 20:
                # %memit dipole([0, 0, zsrc], rec, depth, res, freq, ab=ab, ht=HT, htarg=HTARG, opt=opt, verb=0)

            runtimes[HTP][opt][case] = 1000*out.best
            print(u'%10.1f ms :: ' % runtimes[HTP][opt][case] + '  ** Layers ::', nlay, '; Offsets ::', noff, '**')
            
print('   **   FINISHED   **')
# Out:
#    **   9pt QWE; opt = None   **
#        6.7 ms ::   ** Layers :: 5 ; Offsets :: 1 **
#       10.8 ms ::   ** Layers :: 5 ; Offsets :: 3 **
#       15.7 ms ::   ** Layers :: 5 ; Offsets :: 10 **
#       22.2 ms ::   ** Layers :: 5 ; Offsets :: 31 **
#       41.2 ms ::   ** Layers :: 5 ; Offsets :: 100 **
#       98.6 ms ::   ** Layers :: 5 ; Offsets :: 316 **
#      308.9 ms ::   ** Layers :: 5 ; Offsets :: 1000 **
#       11.9 ms ::   ** Layers :: 22 ; Offsets :: 1 **
#       19.4 ms ::   ** Layers :: 22 ; Offsets :: 3 **
#       30.9 ms ::   ** Layers :: 22 ; Offsets :: 10 **
#       48.5 ms ::   ** Layers :: 22 ; Offsets :: 31 **
#      103.2 ms ::   ** Layers :: 22 ; Offsets :: 100 **
#      265.0 ms ::   ** Layers :: 22 ; Offsets :: 316 **
#      835.6 ms ::   ** Layers :: 22 ; Offsets :: 1000 **
#       33.5 ms ::   ** Layers :: 100 ; Offsets :: 1 **
#       47.8 ms ::   ** Layers :: 100 ; Offsets :: 3 **
#       80.1 ms ::   ** Layers :: 100 ; Offsets :: 10 **
#      145.6 ms ::   ** Layers :: 100 ; Offsets :: 31 **
#      353.1 ms ::   ** Layers :: 100 ; Offsets :: 100 **
#     1001.6 ms ::   ** Layers :: 100 ; Offsets :: 316 **
# peak memory: 136.86 MiB, increment: 24.54 MiB
#     3096.7 ms ::   ** Layers :: 100 ; Offsets :: 1000 **
#    **   9pt QWE; opt = parallel   **
#       14.6 ms ::   ** Layers :: 5 ; Offsets :: 1 **
#       21.9 ms ::   ** Layers :: 5 ; Offsets :: 3 **
#       28.0 ms ::   ** Layers :: 5 ; Offsets :: 10 **
#       32.7 ms ::   ** Layers :: 5 ; Offsets :: 31 **
#       45.0 ms ::   ** Layers :: 5 ; Offsets :: 100 **
#       71.1 ms ::   ** Layers :: 5 ; Offsets :: 316 **
#      183.7 ms ::   ** Layers :: 5 ; Offsets :: 1000 **
#       37.7 ms ::   ** Layers :: 22 ; Offsets :: 1 **
#       56.2 ms ::   ** Layers :: 22 ; Offsets :: 3 **
#       77.2 ms ::   ** Layers :: 22 ; Offsets :: 10 **
#       90.6 ms ::   ** Layers :: 22 ; Offsets :: 31 **
#      131.3 ms ::   ** Layers :: 22 ; Offsets :: 100 **
#      217.8 ms ::   ** Layers :: 22 ; Offsets :: 316 **
#      551.6 ms ::   ** Layers :: 22 ; Offsets :: 1000 **
#      141.2 ms ::   ** Layers :: 100 ; Offsets :: 1 **
#      185.5 ms ::   ** Layers :: 100 ; Offsets :: 3 **
#      240.6 ms ::   ** Layers :: 100 ; Offsets :: 10 **
#      297.3 ms ::   ** Layers :: 100 ; Offsets :: 31 **
#      455.9 ms ::   ** Layers :: 100 ; Offsets :: 100 **
#      825.3 ms ::   ** Layers :: 100 ; Offsets :: 316 **
# peak memory: 129.32 MiB, increment: 17.89 MiB
#     1997.6 ms ::   ** Layers :: 100 ; Offsets :: 1000 **
#    **   9pt QWE; opt = spline   **
#        3.3 ms ::   ** Layers :: 5 ; Offsets :: 1 **
#       13.6 ms ::   ** Layers :: 5 ; Offsets :: 3 **
#       15.2 ms ::   ** Layers :: 5 ; Offsets :: 10 **
#       19.7 ms ::   ** Layers :: 5 ; Offsets :: 31 **
#       34.2 ms ::   ** Layers :: 5 ; Offsets :: 100 **
#       79.8 ms ::   ** Layers :: 5 ; Offsets :: 316 **
#      224.4 ms ::   ** Layers :: 5 ; Offsets :: 1000 **
#        4.2 ms ::   ** Layers :: 22 ; Offsets :: 1 **
#       14.6 ms ::   ** Layers :: 22 ; Offsets :: 3 **
#       16.2 ms ::   ** Layers :: 22 ; Offsets :: 10 **
#       20.7 ms ::   ** Layers :: 22 ; Offsets :: 31 **
#       35.2 ms ::   ** Layers :: 22 ; Offsets :: 100 **
#       80.6 ms ::   ** Layers :: 22 ; Offsets :: 316 **
#      227.8 ms ::   ** Layers :: 22 ; Offsets :: 1000 **
#        8.2 ms ::   ** Layers :: 100 ; Offsets :: 1 **
#       14.7 ms ::   ** Layers :: 100 ; Offsets :: 3 **
#       20.9 ms ::   ** Layers :: 100 ; Offsets :: 10 **
#       25.4 ms ::   ** Layers :: 100 ; Offsets :: 31 **
#       40.2 ms ::   ** Layers :: 100 ; Offsets :: 100 **
#       84.7 ms ::   ** Layers :: 100 ; Offsets :: 316 **
# peak memory: 128.62 MiB, increment: 30.10 MiB
#      228.1 ms ::   ** Layers :: 100 ; Offsets :: 1000 **
#    **   201pt FHT; opt = None   **
#        1.3 ms ::   ** Layers :: 5 ; Offsets :: 1 **
#        2.0 ms ::   ** Layers :: 5 ; Offsets :: 3 **
#        4.4 ms ::   ** Layers :: 5 ; Offsets :: 10 **
#       11.6 ms ::   ** Layers :: 5 ; Offsets :: 31 **
#       35.4 ms ::   ** Layers :: 5 ; Offsets :: 100 **
#      114.6 ms ::   ** Layers :: 5 ; Offsets :: 316 **
#      388.3 ms ::   ** Layers :: 5 ; Offsets :: 1000 **
#        2.4 ms ::   ** Layers :: 22 ; Offsets :: 1 **
#        4.6 ms ::   ** Layers :: 22 ; Offsets :: 3 **
#       11.7 ms ::   ** Layers :: 22 ; Offsets :: 10 **
#       33.4 ms ::   ** Layers :: 22 ; Offsets :: 31 **
#      105.9 ms ::   ** Layers :: 22 ; Offsets :: 100 **
#      345.0 ms ::   ** Layers :: 22 ; Offsets :: 316 **
#     1317.7 ms ::   ** Layers :: 22 ; Offsets :: 1000 **
#        7.4 ms ::   ** Layers :: 100 ; Offsets :: 1 **
#       16.2 ms ::   ** Layers :: 100 ; Offsets :: 3 **
#       45.0 ms ::   ** Layers :: 100 ; Offsets :: 10 **
#      132.2 ms ::   ** Layers :: 100 ; Offsets :: 31 **
#      421.7 ms ::   ** Layers :: 100 ; Offsets :: 100 **
#     1587.1 ms ::   ** Layers :: 100 ; Offsets :: 316 **
# peak memory: 1049.32 MiB, increment: 902.47 MiB
#     5505.0 ms ::   ** Layers :: 100 ; Offsets :: 1000 **
#    **   201pt FHT; opt = parallel   **
#        2.1 ms ::   ** Layers :: 5 ; Offsets :: 1 **
#        2.9 ms ::   ** Layers :: 5 ; Offsets :: 3 **
#        5.0 ms ::   ** Layers :: 5 ; Offsets :: 10 **
#        6.1 ms ::   ** Layers :: 5 ; Offsets :: 31 **
#       12.4 ms ::   ** Layers :: 5 ; Offsets :: 100 **
#       32.9 ms ::   ** Layers :: 5 ; Offsets :: 316 **
#      113.5 ms ::   ** Layers :: 5 ; Offsets :: 1000 **
#        5.2 ms ::   ** Layers :: 22 ; Offsets :: 1 **
#        7.3 ms ::   ** Layers :: 22 ; Offsets :: 3 **
#       13.6 ms ::   ** Layers :: 22 ; Offsets :: 10 **
#       18.1 ms ::   ** Layers :: 22 ; Offsets :: 31 **
#       36.7 ms ::   ** Layers :: 22 ; Offsets :: 100 **
#       94.6 ms ::   ** Layers :: 22 ; Offsets :: 316 **
#      309.8 ms ::   ** Layers :: 22 ; Offsets :: 1000 **
#       17.7 ms ::   ** Layers :: 100 ; Offsets :: 1 **
#       25.9 ms ::   ** Layers :: 100 ; Offsets :: 3 **
#       49.6 ms ::   ** Layers :: 100 ; Offsets :: 10 **
#       70.1 ms ::   ** Layers :: 100 ; Offsets :: 31 **
#      142.6 ms ::   ** Layers :: 100 ; Offsets :: 100 **
#      372.6 ms ::   ** Layers :: 100 ; Offsets :: 316 **
# peak memory: 761.67 MiB, increment: 614.46 MiB
#     1202.3 ms ::   ** Layers :: 100 ; Offsets :: 1000 **
#    **   201pt FHT; opt = spline   **
#        1.3 ms ::   ** Layers :: 5 ; Offsets :: 1 **
#        1.5 ms ::   ** Layers :: 5 ; Offsets :: 3 **
#        1.6 ms ::   ** Layers :: 5 ; Offsets :: 10 **
#        1.6 ms ::   ** Layers :: 5 ; Offsets :: 31 **
#        1.7 ms ::   ** Layers :: 5 ; Offsets :: 100 **
#        1.8 ms ::   ** Layers :: 5 ; Offsets :: 316 **
#        2.2 ms ::   ** Layers :: 5 ; Offsets :: 1000 **
#        2.4 ms ::   ** Layers :: 22 ; Offsets :: 1 **
#        2.7 ms ::   ** Layers :: 22 ; Offsets :: 3 **
#        2.8 ms ::   ** Layers :: 22 ; Offsets :: 10 **
#        2.9 ms ::   ** Layers :: 22 ; Offsets :: 31 **
#        2.9 ms ::   ** Layers :: 22 ; Offsets :: 100 **
#        3.1 ms ::   ** Layers :: 22 ; Offsets :: 316 **
#        3.5 ms ::   ** Layers :: 22 ; Offsets :: 1000 **
#        7.4 ms ::   ** Layers :: 100 ; Offsets :: 1 **
#        8.1 ms ::   ** Layers :: 100 ; Offsets :: 3 **
#        8.4 ms ::   ** Layers :: 100 ; Offsets :: 10 **
#        8.5 ms ::   ** Layers :: 100 ; Offsets :: 31 **
#        8.6 ms ::   ** Layers :: 100 ; Offsets :: 100 **
#        8.7 ms ::   ** Layers :: 100 ; Offsets :: 316 **
# peak memory: 148.30 MiB, increment: 0.00 MiB
#        9.2 ms ::   ** Layers :: 100 ; Offsets :: 1000 **
#    **   801pt FHT; opt = None   **
#        2.1 ms ::   ** Layers :: 5 ; Offsets :: 1 **
#        4.3 ms ::   ** Layers :: 5 ; Offsets :: 3 **
#       11.9 ms ::   ** Layers :: 5 ; Offsets :: 10 **
#       35.3 ms ::   ** Layers :: 5 ; Offsets :: 31 **
#      119.7 ms ::   ** Layers :: 5 ; Offsets :: 100 **
#      412.3 ms ::   ** Layers :: 5 ; Offsets :: 316 **
#     1503.8 ms ::   ** Layers :: 5 ; Offsets :: 1000 **
#        4.9 ms ::   ** Layers :: 22 ; Offsets :: 1 **
#       11.8 ms ::   ** Layers :: 22 ; Offsets :: 3 **
#       36.2 ms ::   ** Layers :: 22 ; Offsets :: 10 **
#      111.0 ms ::   ** Layers :: 22 ; Offsets :: 31 **
#      379.8 ms ::   ** Layers :: 22 ; Offsets :: 100 **
#     1467.7 ms ::   ** Layers :: 22 ; Offsets :: 316 **
#     4887.5 ms ::   ** Layers :: 22 ; Offsets :: 1000 **
#       17.3 ms ::   ** Layers :: 100 ; Offsets :: 1 **
#       46.3 ms ::   ** Layers :: 100 ; Offsets :: 3 **
#      146.6 ms ::   ** Layers :: 100 ; Offsets :: 10 **
#      451.8 ms ::   ** Layers :: 100 ; Offsets :: 31 **
#     1788.1 ms ::   ** Layers :: 100 ; Offsets :: 100 **
#     6238.1 ms ::   ** Layers :: 100 ; Offsets :: 316 **
# peak memory: 3897.65 MiB, increment: 3765.75 MiB
#    17963.2 ms ::   ** Layers :: 100 ; Offsets :: 1000 **
#    **   801pt FHT; opt = parallel   **
#        3.8 ms ::   ** Layers :: 5 ; Offsets :: 1 **
#        5.4 ms ::   ** Layers :: 5 ; Offsets :: 3 **
#        8.3 ms ::   ** Layers :: 5 ; Offsets :: 10 **
#       17.9 ms ::   ** Layers :: 5 ; Offsets :: 31 **
#       50.3 ms ::   ** Layers :: 5 ; Offsets :: 100 **
#      165.4 ms ::   ** Layers :: 5 ; Offsets :: 316 **
#      508.8 ms ::   ** Layers :: 5 ; Offsets :: 1000 **
#        9.7 ms ::   ** Layers :: 22 ; Offsets :: 1 **
#       15.5 ms ::   ** Layers :: 22 ; Offsets :: 3 **
#       24.2 ms ::   ** Layers :: 22 ; Offsets :: 10 **
#       52.4 ms ::   ** Layers :: 22 ; Offsets :: 31 **
#      151.7 ms ::   ** Layers :: 22 ; Offsets :: 100 **
#      462.8 ms ::   ** Layers :: 22 ; Offsets :: 316 **
#     1408.7 ms ::   ** Layers :: 22 ; Offsets :: 1000 **
#       36.3 ms ::   ** Layers :: 100 ; Offsets :: 1 **
#       61.0 ms ::   ** Layers :: 100 ; Offsets :: 3 **
#       96.6 ms ::   ** Layers :: 100 ; Offsets :: 10 **
#      203.5 ms ::   ** Layers :: 100 ; Offsets :: 31 **
#      573.7 ms ::   ** Layers :: 100 ; Offsets :: 100 **
#     1824.6 ms ::   ** Layers :: 100 ; Offsets :: 316 **
# peak memory: 2705.22 MiB, increment: 2627.55 MiB
#     5507.6 ms ::   ** Layers :: 100 ; Offsets :: 1000 **
#    **   801pt FHT; opt = spline   **
#        2.1 ms ::   ** Layers :: 5 ; Offsets :: 1 **
#        2.5 ms ::   ** Layers :: 5 ; Offsets :: 3 **
#        2.6 ms ::   ** Layers :: 5 ; Offsets :: 10 **
#        2.7 ms ::   ** Layers :: 5 ; Offsets :: 31 **
#        2.8 ms ::   ** Layers :: 5 ; Offsets :: 100 **
#        3.0 ms ::   ** Layers :: 5 ; Offsets :: 316 **
#        3.4 ms ::   ** Layers :: 5 ; Offsets :: 1000 **
#        4.9 ms ::   ** Layers :: 22 ; Offsets :: 1 **
#        5.4 ms ::   ** Layers :: 22 ; Offsets :: 3 **
#        5.6 ms ::   ** Layers :: 22 ; Offsets :: 10 **
#        5.8 ms ::   ** Layers :: 22 ; Offsets :: 31 **
#        5.9 ms ::   ** Layers :: 22 ; Offsets :: 100 **
#        5.9 ms ::   ** Layers :: 22 ; Offsets :: 316 **
#        6.4 ms ::   ** Layers :: 22 ; Offsets :: 1000 **
#       17.3 ms ::   ** Layers :: 100 ; Offsets :: 1 **
#       18.7 ms ::   ** Layers :: 100 ; Offsets :: 3 **
#       19.0 ms ::   ** Layers :: 100 ; Offsets :: 10 **
#       19.4 ms ::   ** Layers :: 100 ; Offsets :: 31 **
#       19.3 ms ::   ** Layers :: 100 ; Offsets :: 100 **
#       19.5 ms ::   ** Layers :: 100 ; Offsets :: 316 **
# peak memory: 78.11 MiB, increment: 0.09 MiB
#       19.9 ms ::   ** Layers :: 100 ; Offsets :: 1000 **
#    **   FINISHED   **

# %% [markdown]
# ## Figure Normal/Parallel/Spline

# %%
for i in range(np.size(aHT)):
    x = np.arange(7)
    
    lw1 = 1.5
    
    fig = plt.figure()
    plt.title(aHTP[i], fontsize=20)
    plt.plot(-1, 1, 'k-', lw=lw1, label='5 layers')
    plt.plot(-1, 1, 'k--', lw=lw1, label='22 layers')
    plt.plot(-1, 1, 'k:', lw=lw1, label='100 layers')
    plt.plot(-1, 1, 'r', lw=lw1, label='None')
    plt.plot(-1, 1, 'b', lw=lw1, label=aOPT[1])
    plt.plot(-1, 1, 'g', lw=lw1, label=aOPT[2])

    plt.semilogy(x, runtimes[aHTP[i]][aOPT[0]][:7], 'r-', lw=lw1)
    plt.semilogy(x, runtimes[aHTP[i]][aOPT[0]][7:14], 'r--', lw=lw1)
    plt.semilogy(x, runtimes[aHTP[i]][aOPT[0]][14:], 'r:', lw=lw1)
    plt.semilogy(x, runtimes[aHTP[i]][aOPT[1]][:7], 'b-', lw=lw1)
    plt.semilogy(x, runtimes[aHTP[i]][aOPT[1]][7:14], 'b--', lw=lw1)
    plt.semilogy(x, runtimes[aHTP[i]][aOPT[1]][14:], 'b:', lw=lw1)
    plt.semilogy(x, runtimes[aHTP[i]][aOPT[2]][:7], 'g-', lw=lw1)
    plt.semilogy(x, runtimes[aHTP[i]][aOPT[2]][7:14], 'g--', lw=lw1)
    plt.semilogy(x, runtimes[aHTP[i]][aOPT[2]][14:], 'g:', lw=lw1)

    plt.xticks([0,1,2,3,4,5,6], (1, 3, 10, 32, 100, 316, 1000))
    plt.xlabel(r'\# offsets', fontsize=14)
    plt.ylabel(r'Time (ms)', fontsize=14)
    plt.legend(loc='best', fontsize=12, ncol=2)
    plt.xlim([-.2, 6.2])

    plt.show()
# Out:
# /home/dwerthmuller/anaconda3/lib/python3.5/site-packages/matplotlib/axes/_base.py:3179: UserWarning: Attempting to set identical bottom==top results
# in singular transformations; automatically expanding.
# bottom=1.0, top=1.0
#   'bottom=%s, top=%s') % (bottom, top))
# /home/dwerthmuller/anaconda3/lib/python3.5/site-packages/matplotlib/axes/_base.py:3179: UserWarning: Attempting to set identical bottom==top results
# in singular transformations; automatically expanding.
# bottom=1.0, top=1.0
#   'bottom=%s, top=%s') % (bottom, top))

# %% [markdown]
# ## Figure QWE/FHT

# %%
for i in range(np.size(aOPT)):
    x = np.arange(7)
    
    lw1 = 1.5
    
    fig = plt.figure()
    plt.title(aOPT[i], fontsize=20)
    plt.plot(-1, 1, 'k-', lw=lw1, label='5 layers')
    plt.plot(-1, 1, 'k--', lw=lw1, label='22 layers')
    plt.plot(-1, 1, 'k:', lw=lw1, label='100 layers')
    plt.plot(-1, 1, 'r', lw=lw1, label=aHTP[0])
    plt.plot(-1, 1, 'b', lw=lw1, label=aHTP[1])
    plt.plot(-1, 1, 'g', lw=lw1, label=aHTP[2])

    plt.semilogy(x, runtimes[aHTP[0]][aOPT[i]][:7], 'r-', lw=lw1)
    plt.semilogy(x, runtimes[aHTP[0]][aOPT[i]][7:14], 'r--', lw=lw1)
    plt.semilogy(x, runtimes[aHTP[0]][aOPT[i]][14:], 'r:', lw=lw1)
    
    plt.semilogy(x, runtimes[aHTP[1]][aOPT[i]][:7], 'b-', lw=lw1)
    plt.semilogy(x, runtimes[aHTP[1]][aOPT[i]][7:14], 'b--', lw=lw1)
    plt.semilogy(x, runtimes[aHTP[1]][aOPT[i]][14:], 'b:', lw=lw1)
    
    plt.semilogy(x, runtimes[aHTP[2]][aOPT[i]][:7], 'g-', lw=lw1)
    plt.semilogy(x, runtimes[aHTP[2]][aOPT[i]][7:14], 'g--', lw=lw1)
    plt.semilogy(x, runtimes[aHTP[2]][aOPT[i]][14:], 'g:', lw=lw1)

    plt.xticks([0,1,2,3,4,5,6], (1, 3, 10, 32, 100, 316, 1000))
    plt.xlabel(r'\# offsets', fontsize=14)
    plt.ylabel(r'Time (ms)', fontsize=14)
    plt.legend(loc='best', fontsize=12, ncol=2)
    plt.xlim([-.2, 6.2])

    plt.show()
# Out:
# /home/dwerthmuller/anaconda3/lib/python3.5/site-packages/matplotlib/axes/_base.py:3179: UserWarning: Attempting to set identical bottom==top results
# in singular transformations; automatically expanding.
# bottom=1.0, top=1.0
#   'bottom=%s, top=%s') % (bottom, top))

# %% [markdown]
# ## Error levels

# %%
nlay = 22      # Nr of layers: 5, 22, 100
depth = np.r_[0, 1000+np.linspace(0, 5000, nlay-2)]  # Layer top depths
res = np.r_[1e20, 0.3, np.linspace(.1, 10, nlay-2)]  # Layer resistivities (ohm-m)

noff = 100                           # Nr of offsets: 1, 10, 100, 1000
rec   = [np.linspace(500, min(20000, noff*500+500), noff), np.zeros(noff), zrec]

ref = dipole([0, 0, zsrc], rec, depth, res, freq, ab=ab, ht=aHT[0], htarg=[1e-14, 1e-24, 51], opt=False, verb=0)

qwe = dipole([0, 0, zsrc], rec, depth, res, freq, ab=ab, ht=aHT[0], htarg=aHTARG[0], opt=None, verb=0)
qwesp = dipole([0, 0, zsrc], rec, depth, res, freq, ab=ab, ht=aHT[0], htarg=aHTARG[0], opt='spline', verb=0)

fht201 = dipole([0, 0, zsrc], rec, depth, res, freq, ab=ab, ht=aHT[1], htarg=aHTARG[1], opt=None, verb=0)
fht201sp = dipole([0, 0, zsrc], rec, depth, res, freq, ab=ab, ht=aHT[1], htarg=aHTARG[1], opt='spline', verb=0)

fht801 = dipole([0, 0, zsrc], rec, depth, res, freq, ab=ab, ht=aHT[2], htarg=aHTARG[2], opt=None, verb=0)
fht801sp = dipole([0, 0, zsrc], rec, depth, res, freq, ab=ab, ht=aHT[2], htarg=aHTARG[2], opt='spline', verb=0)

# %%
# Figure
fig = plt.figure(figsize=(10,6))
plt.title(r'Relative Error $|E|$ log10')
plt.xlabel('Offset (m)')

## ABS ERROR ##
plt.plot(rec[0], np.log10(np.abs((qwe-ref)/ref)), 'r', label='9pt QWE')
plt.plot(rec[0], np.log10(np.abs((qwesp-ref)/ref)), 'r--', label='9pt QWE spline')
plt.plot(rec[0], np.log10(np.abs((fht201-ref)/ref)), 'b-', label='201pt FHT')
plt.plot(rec[0], np.log10(np.abs((fht201sp-ref)/ref)), 'b--', label='201pt FHT spline')
plt.plot(rec[0], np.log10(np.abs((fht801-ref)/ref)), 'g-', label='801pt FHT')
plt.plot(rec[0], np.log10(np.abs((fht801sp-ref)/ref)), 'g--', label='801pt FHT spline')

plt.legend(loc='lower center', ncol=3)
plt.show()
